# %%
# !nvidia-smi
# Out:
# Tue Nov 28 17:56:18 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   67C    P8    12W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 646.0/646.0 kB 8.4 MB/s eta 0:00:00
# ...

# %%
import torch
torch.cuda.is_available()
# Out:
# False

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/object_detection/Smoke_Detector/
# Out:
# /content/drive/MyDrive/object_detection/Smoke_Detector

# %%
from ultralytics import YOLO
import cv2
import numpy as np
import PIL
import matplotlib.pyplot as plt

# %%
model = YOLO("yolov8n.pt")

# %%
model.train(data="data.yaml", epochs=200)
# Out:
# Ultralytics YOLOv8.0.219 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
metrics = model.val()
# Out:
# Ultralytics YOLOv8.0.217 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3008768 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /content/drive/MyDrive/object_detection/Smoke_Detector/Data/val/labels.cache... 4185 images, 0 backgrounds, 1954 corrupt: 100%|██████████| 4185/4185 [00:00<?, ?it/s]
# val: WARNING ⚠️ /content/drive/MyDrive/object_detection/Smoke_Detector/Data/val/images/H_00002.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0893]
# val: WARNING ⚠️ /content/drive/MyDrive/object_detection/Smoke_Detector/Data/val/images/H_00003.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0045]
# val: WARNING ⚠️ /content/drive/MyDrive/object_detection/Smoke_Detector/Data/val/images/H_00008.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.1786]
# ...

# %%
model = YOLO("/content/drive/MyDrive/object_detection/Smoke_Detector/runs/detect/train6/weights/best.pt")

# %%
# %cd /content/
# Out:
# /content

# %%
model.predict("download.jpg")
# Out:
# image 1/1 /content/download.jpg: 352x640 1 Smoke, 302.3ms
# Speed: 2.8ms preprocess, 302.3ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'dog', 1: 'person', 2: 'cat', 3: 'tv', 4: 'car', 5: 'meatballs', 6: 'marinara sauce', 7: 'tomato soup', 8: 'chicken noodle soup', 9: 'french onion soup', 10: 'chicken breast', 11: 'ribs', 12: 'pulled pork', 13: 'hamburger', 14: 'cavity', 15: 'Smoke'}
#  orig_img: array([[[237, 233, 232],
#          [237, 233, 232],
#          [238, 234, 233],
#          ...,
#          [ 30,  30,  36],
#          [ 30,  30,  36],
#          [ 30,  30,  36]],
#
#         [[237, 233, 232],
#          [238, 234, 233],
#          [238, 234, 233],
#          ...,
#          [ 30,  30,  36],
#          [ 30,  30,  36],
#          [ 30,  30,  36]],
#
#         [[238, 234, 233],
# ...

# %%
results = model.predict("/content/drive/MyDrive/object_detection/Smoke_Detector/images/013e51cf-1999-44ac-8004-542a0de4026f.JPG",stream=True)
